# %%
from sympy import *
import sympy as sp
import numpy as np
from sympy.physics.quantum import TensorProduct
import matplotlib.pyplot as plt 
import math
from math import *
from IPython.display import Image
init_printing()

# %%
a = sp.Matrix([[3,4,-5],[8,7,-2],[2,-1,8]])
det(a)
# Out:
# 0

# %%
a = Symbol('alpha')
b = Symbol('beta')
y = Symbol('gamma')
b = sp.Matrix([[a**2+1, a*b, a*y],[a*b,b**2+1,b*y],[a*y,b*y,y**2+1]])
det(b)
# Out:
#  2    2    2
# α  + β  + γ  + 1

# %% [markdown]
# Image(filename='/Users/nikolaysedoff/PycharmProjects/ITiABD-PM22-7-Nikolay-Sedov/ALGEO/pg7/page7.ipynb')

# %%
a = sp.Matrix([[-3,4,1],[-2,3,2],[-1,4,3]])
det(a)
# Out:
# 8

# %%
b = sp.Matrix([[2,4,1],[4,3,2],[3,4,3]])
det(b)
# Out:
# -15

# %%
c = sp.Matrix([[2,-3,1],[4,-2,2],[3,-1,3]])
det(c)
# Out:
# 12

# %%
d = sp.Matrix([[2,-3,4],[4,-2,3],[3,-1,4]])
det(d)
# Out:
# 19

# %%
A = sp.Matrix([[8,-15],[12,19]])
A.det()
# Out:
# 332

# %%
a = sp.Matrix([[4,4,-3],[2,3,-2],[4,5,-4]])
a.det()
# Out:
# -2

# %%
b = sp.Matrix([[5,2,-1],[2,3,-2],[4,5,-4]])
b.det()
# Out:
# -8

# %%
c = sp.Matrix([[5,2,-1],[4,4,-3],[4,5,-4]])
c.det()
# Out:
# -1

# %%
d = sp.Matrix([[5,2,-1],[4,4,-3],[2,3,-2]])
d.det()
# Out:
# 5

# %%
A = sp.Matrix([[-2,-8],[-1,5]])
A.det()
# Out:
# -18

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = sp.Matrix([[1,2,3,4],[-3,2,-5,13],[1,-2,10,4],[-2,9,-8,25]])
x = a.echelon_form()
x.det()
# Out:
# 1387008

# %%
b = sp.Matrix([[1001,1002,1003,1004],[1002,1003,1001,1002],[1001,1001,1001,999],[1001,1000,998,999]])
c = b.echelon_form()
c.det()
# Out:
# 54318781020750294048

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = sp.Matrix([[1,2],[3,4]])
abs(a.det())
# Out:
# 2

# %% [markdown]
# ![Screenshot 2022-11-02 at 20.07.14.png](attachment:/Users/nikolaysedoff/PycharmProjects/ITiABD-PM22-7-Nikolay-Sedov/ALGEO/pg7/page7.ipynb)

# %%
from sympy import *
a = Symbol('a')
b = Symbol('b')
c = Symbol('c')
d = Symbol('d')
S = sp.Matrix([[a**2+b**2,a*c+b*d],[a*c+b*d,c**2+d**2]])
S.det()
# Out:
# a**2*d**2 - 2*a*b*c*d + b**2*c**2

# %%
S1 = sp.Matrix([[a,b],[c,d]])
det(S1**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 S1 = sp.Matrix([[a,b],[c,d]])
#       2 det(S1**2)
#
# NameError: name 'a' is not defined

# %%
S.det() == det(S1**2)
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#a
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
y1 = Symbol('y1')
y2 = Symbol('y2')
y3 = Symbol('y3')
y4 = Symbol('y4')
z1 = Symbol('z1')
z2 = Symbol('z2')
z3 = Symbol('z3')
z4 = Symbol('z4')
A = sp.Matrix([[x1,y1,z1,1],[x2,y2,z2,1],[x3,y3,z3,1],[x4,y4,z4,1]])
A.det()
V = 1/6 * A
V, A.det()
# Out:
# ⎛⎡0.166666666666667⋅x₁  0.166666666666667⋅y₁  0.166666666666667⋅z₁  0.16666666
# ⎜⎢
# ⎜⎢0.166666666666667⋅x₂  0.166666666666667⋅y₂  0.166666666666667⋅z₂  0.16666666
# ⎜⎢
# ⎜⎢0.166666666666667⋅x₃  0.166666666666667⋅y₃  0.166666666666667⋅z₃  0.16666666
# ⎜⎢
# ⎝⎣0.166666666666667⋅x₄  0.166666666666667⋅y₄  0.166666666666667⋅z₄  0.16666666
#
# 6666667⎤
#        ⎥
# 6666667⎥
#        ⎥, x₁⋅y₂⋅z₃ - x₁⋅y₂⋅z₄ - x₁⋅y₃⋅z₂ + x₁⋅y₃⋅z₄ + x₁⋅y₄⋅z₂ - x₁⋅y₄⋅z₃ - x₂
# 6666667⎥
#        ⎥
# 6666667⎦
#
#
#
#
# ⋅y₁⋅z₃ + x₂⋅y₁⋅z₄ + x₂⋅y₃⋅z₁ - x₂⋅y₃⋅z₄ - x₂⋅y₄⋅z₁ + x₂⋅y₄⋅z₃ + x₃⋅y₁⋅z₂ - x₃⋅
#
#
#
#
#
#
#
# y₁⋅z₄ - x₃⋅y₂⋅z₁ + x₃⋅y₂⋅z₄ + x₃⋅y₄⋅z₁ - x₃⋅y₄⋅z₂ - x₄⋅y₁⋅z₂ + x₄⋅y₁⋅z₃ + x₄⋅y
#
#
#
#
#                                      ⎞
#                                      ⎟
#                                      ⎟
# ₂⋅z₁ - x₄⋅y₂⋅z₃ - x₄⋅y₃⋅z₁ + x₄⋅y₃⋅z₂⎟
#                                      ⎟
#                                      ⎟
#                                      ⎠

# %%
import sympy as sp
A = sp.Matrix([[-1,1,2,1],[0,3,3,1],[1,-1,2,1],[0,0,1,1]])
x = 1/6 * abs(A.det())
x
# Out:
# 1.00000000000000

# %%
A = sp.Matrix([[1,2,1],[2,-2,0],[1,1,-1]])
A.det()
# Out:
# 10

# %%
q = 1/6 * 10
q
# Out:
# 1.6666666666666665

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = Symbol('alpha')
a1 = Symbol('a1')
a2 = Symbol('a2')
a3 = Symbol('a3')
b = Symbol('beta')
b1 = Symbol('b1')
b2 = Symbol('b2')
b3 = Symbol('b3')
y = Symbol('gamma')
c1 = Symbol('c1')
c2 = Symbol('c2')
c3 = Symbol('c3')
A = sp.Matrix([[a*a2+a3,b*a3+a1,y*a1+a2],[a*b2+b3,b*b3+b1,y*b1+b2],[a*c2+c3,b*c3+c1,y*c1+c2]])
B = sp.Matrix([[a1,a2,a3],[b1,b2,b3],[c1,c2,c3]])
C = (1+a*b*y)*B
A,C
# Out:
# ⎛⎡a₂⋅α + a₃  a₁ + a₃⋅β  a₁⋅γ + a₂⎤  ⎡a₁⋅(α⋅β⋅γ + 1)  a₂⋅(α⋅β⋅γ + 1)  a₃⋅(α⋅β⋅γ
# ⎜⎢                               ⎥  ⎢
# ⎜⎢α⋅b₂ + b₃  b₁ + b₃⋅β  b₁⋅γ + b₂⎥, ⎢b₁⋅(α⋅β⋅γ + 1)  b₂⋅(α⋅β⋅γ + 1)  b₃⋅(α⋅β⋅γ
# ⎜⎢                               ⎥  ⎢
# ⎝⎣α⋅c₂ + c₃  β⋅c₃ + c₁  c₁⋅γ + c₂⎦  ⎣c₁⋅(α⋅β⋅γ + 1)  c₂⋅(α⋅β⋅γ + 1)  c₃⋅(α⋅β⋅γ
#
#  + 1)⎤⎞
#      ⎥⎟
#  + 1)⎥⎟
#      ⎥⎟
#  + 1)⎦⎠

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy as sp
detmax = -100000000
for x1 in (0,1):
    for x2 in (0,1):
        for x3 in (0,1):
            for x4 in (0,1):
                for x5 in (0,1):
                    for x6 in (0,1):
                        for x7 in (0,1):
                            for x8 in (0,1):
                                for x9 in (0,1):
                                    A = sp.Matrix(3,3,(x1,x2,x3,x4,x5,x6,x7,x8,x9))
                                    if sp.det(A)>detmax:
                                        detmax = sp.det(A)
print(detmax)
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = sp.Symbol('x')
y = sp.Symbol('y')
z = sp.Symbol('z')
A = sp.Matrix(3,3,[
    x**3+1,x**2,x,
    y**3+1,y**2,y,
    z**3+1,z**2,z
])
A.det()
solve(A.det())
# Out:
# ⎡                ⎧   -1 ⎫        ⎤
# ⎢{x: y}, {x: z}, ⎨x: ───⎬, {y: z}⎥
# ⎣                ⎩   y⋅z⎭        ⎦
