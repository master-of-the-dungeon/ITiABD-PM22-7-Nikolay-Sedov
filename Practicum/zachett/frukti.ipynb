# %%
import tkinter as tk
import random

def create_fruit():
    x = random.randint(50, 550)
    y = random.randint(50, 550)
    fruit_type = random.choice(fruit_images)
    fruit = canvas.create_image(x, y, anchor=tk.CENTER, image=fruit_type)
    fruits.append((fruit, (x, y)))
    canvas.after(3000, delete_fruit, fruit)
    # Планируем создание следующего фрукта
    canvas.after(1000, create_fruit)

def delete_fruit(fruit):
    canvas.delete(fruit)
    fruits.remove(fruit)

def collect(event):
    global score
    x, y = event.x, event.y
    for fruit, (fx, fy) in list(fruits):  # Используем копию списка, чтобы избежать изменений во время итерации
        if fx - 25 < x < fx + 25 and fy - 25 < y < fy + 25:
            canvas.delete(fruit)
            fruits.remove((fruit, (fx, fy)))
            score += 1
            score_label.config(text=f"Score: {score}")
            break

root = tk.Tk()
root.title("Собери фрукты")

canvas = tk.Canvas(root, width=600, height=600, bg='lightgreen')
canvas.pack()

# Загрузка измененных изображений фруктов
apple_img = tk.PhotoImage(file="resized_apple.png")
banana_img = tk.PhotoImage(file="resized_banana.png")
orange_img = tk.PhotoImage(file="resized_orange.png")

fruit_images = [apple_img, banana_img, orange_img]
fruits = []
score = 0

score_label = tk.Label(root, text="Score: 0", font=("Arial", 18))
score_label.pack()

canvas.bind("<Button-1>", collect)

# Начинаем создание фруктов
create_fruit()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\nsedoff\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\nsedoff\AppData\Local\Temp\ipykernel_23980\2739609997.py", line 16, in delete_fruit
#     fruits.remove(fruit)
# ValueError: list.remove(x): x not in list
