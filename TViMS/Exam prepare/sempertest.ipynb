# %%
# !pip install semper
# Out:
# ...
#      ---------------------------------------- 0.0/20.4 MB ? eta -:--:--
#      --------------------------------------- 0.0/20.4 MB 660.6 kB/s eta 0:00:31
#      ---------------------------------------- 0.1/20.4 MB 1.3 MB/s eta 0:00:16
#       --------------------------------------- 0.3/20.4 MB 3.0 MB/s eta 0:00:07
#      - -------------------------------------- 0.7/20.4 MB 5.2 MB/s eta 0:00:04
#      -- ------------------------------------- 1.0/20.4 MB 6.6 MB/s eta 0:00:03
#      -- ------------------------------------- 1.0/20.4 MB 6.6 MB/s eta 0:00:03
#      -- ------------------------------------- 1.1/20.4 MB 4.3 MB/s eta 0:00:05
#      --- ------------------------------------ 1.5/20.4 MB 5.4 MB/s eta 0:00:04
#      --- ------------------------------------ 1.9/20.4 MB 6.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 2.1/20.4 MB 6.3 MB/s eta 0:00:03
#      ---- ----------------------------------- 2.3/20.4 MB 5.8 MB/s eta 0:00:04
# ...

# %%
from semper import semper

# %%
print(semper.q1.pictures(0))
print('\nimport numpy as np\ndef rrstr(x,n): # округление до n знаков после запятой\n    fmt = \'{:.\'+str(n)+\'f}\'\n    return fmt.format(x).replace(\'.\',\',\')\n\nimport numpy as np\nimport pandas as pd\nimport scipy.integrate as integrate\nimport warnings\nfrom scipy.stats import *\n# import scipy.stats as sts\n\ndef convert(s):\n    s = s.replace(\',\', \'.\').replace(\';\', \',\')\n    data = map(float, s.split(\',\'))\n    return list(data)\n\nZ = norm()\n\ndef Phi0(x):\n    return Z.cdf(x) - 1 / 2\n\nwarnings.filterwarnings("ignore")\n        \n        \n        ',)
# Out:
# ('\nimport numpy as np\ndef rrstr(x,n): # округление до n знаков после запятой\n    fmt = \'{:.\'+str(n)+\'f}\'\n    return fmt.format(x).replace(\'.\',\',\')\n\nimport numpy as np\nimport pandas as pd\nimport scipy.integrate as integrate\nimport warnings\nfrom scipy.stats import *\n# import scipy.stats as sts\n\ndef convert(s):\n    s = s.replace(\',\', \'.\').replace(\';\', \',\')\n    data = map(float, s.split(\',\'))\n    return list(data)\n\nZ = norm()\n\ndef Phi0(x):\n    return Z.cdf(x) - 1 / 2\n\nwarnings.filterwarnings("ignore")\n        \n        \n        ', [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=879x343 at 0x21A483061E0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=924x474 at 0x21A48304D10>])
#
# import numpy as np
# def rrstr(x,n): # округление до n знаков после запятой
#     fmt = '{:.'+str(n)+'f}'
#     return fmt.format(x).replace('.',',')
#
# import numpy as np
# import pandas as pd
# import scipy.integrate as integrate
# import warnings
# ...

# %%
print(semper.q1.pictures(0))
# Out:
# ('\nimport numpy as np\ndef rrstr(x,n): # округление до n знаков после запятой\n    fmt = \'{:.\'+str(n)+\'f}\'\n    return fmt.format(x).replace(\'.\',\',\')\n\nimport numpy as np\nimport pandas as pd\nimport scipy.integrate as integrate\nimport warnings\nfrom scipy.stats import *\n# import scipy.stats as sts\n\ndef convert(s):\n    s = s.replace(\',\', \'.\').replace(\';\', \',\')\n    data = map(float, s.split(\',\'))\n    return list(data)\n\nZ = norm()\n\ndef Phi0(x):\n    return Z.cdf(x) - 1 / 2\n\nwarnings.filterwarnings("ignore")\n        \n        \n        ', [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=879x343 at 0x21A4830A690>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=924x474 at 0x21A4830B2C0>])

# %%
print(semper.q4.pictures(-1,'реализация случайной выборки'))
# Out:
# ('есть в этих номерах: ', [])

# %%
semper.q3.pictures(12)[1][0].resize((600,400))
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
print(semper.q1.pictures(0))
# Out:
# ('\nimport numpy as np\ndef rrstr(x,n): # округление до n знаков после запятой\n    fmt = \'{:.\'+str(n)+\'f}\'\n    return fmt.format(x).replace(\'.\',\',\')\n\nimport numpy as np\nimport pandas as pd\nimport scipy.integrate as integrate\nimport warnings\nfrom scipy.stats import *\n# import scipy.stats as sts\n\ndef convert(s):\n    s = s.replace(\',\', \'.\').replace(\';\', \',\')\n    data = map(float, s.split(\',\'))\n    return list(data)\n\nZ = norm()\n\ndef Phi0(x):\n    return Z.cdf(x) - 1 / 2\n\nwarnings.filterwarnings("ignore")\n        \n        \n        ', [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=879x343 at 0x21A48307CE0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=924x474 at 0x21A48306A50>])
